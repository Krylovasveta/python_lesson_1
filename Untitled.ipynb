# %%
#fom user import user

class User:

    def __init__(self, name):
        print('Hello')
        self.username=name

    def saynam(self):
        print('Hi,', self.username)

u1 = User("Sveta")
u1.saynam()
# Out:
# Hello
# Hi, Sveta
